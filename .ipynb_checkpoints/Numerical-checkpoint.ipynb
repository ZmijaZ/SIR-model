# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# %%
def f1(t, S, I, R):
    N = S + I + R
    return -beta*S*I/N

# %%
def f2(t, S, I, R):
    N = S + I + R
    return beta*S*I/N - gamma*I

# %%
def f3(t, S, I, R):
    N = S + I + R
    return gamma*I

# %%
def params(t0, S0, I0, R0, h, f1, f2, f3):
    k1 = h*f1(t0, S0, I0, R0)
    l1 = h*f2(t0, S0, I0, R0)
    m1 = h*f3(t0, S0, I0, R0)
    
    k2 = h*f1(t0 + h/2, S0 + k1/2, I0 + l1/2, R0 + m1/2) 
    l2 = h*f2(t0 + h/2, S0 + k1/2, I0 + l1/2, R0 + m1/2) 
    m2 = h*f3(t0 + h/2, S0 + k1/2, I0 + l1/2, R0 + m1/2) 
    
    k3 = h*f1(t0 + h/2, S0 + k2/2, I0 + l2/2, R0 + m2/2)
    l3 = h*f2(t0 + h/2, S0 + k2/2, I0 + l2/2, R0 + m2/2)
    m3 = h*f3(t0 + h/2, S0 + k2/2, I0 + l2/2, R0 + m2/2)
    
    k4 = h*f1(t0 + h, S0 + k3, I0 + l3, R0 + m3) 
    l4 = h*f2(t0 + h, S0 + k3, I0 + l3, R0 + m3)
    m4 = h*f3(t0 + h, S0 + k3, I0 + l3, R0 + m3)
    
    ks = [k1, k2, k3, k4]
    ls = [l1, l2, l3, l4]
    ms = [m1, m2, m3, m4]
    
    return ks, ls, ms

# %%
def nextS(S_prev, k1, k2, k3, k4):
    S = S_prev + 1/6*(k1 + 2*k2 + 2*k3 + k4)
    return S

def nextI(I_prev, l1, l2, l3, l4):
    I = I_prev + 1/6*(l1 + 2*l2 + 2*l3 + l4)
    return I

def nextR(R_prev, m1, m2, m3, m4):
    R = R_prev + 1/6*(m1 + 2*m2 + 2*m3 + m4)
    return R

# %%
def SIR_model(num_iters, beta, gamma, S0, I0, R0, t0, h):
    Ss = [S0]
    Is = [I0]
    Rs = [R0]
    ts = [0]
    Ns = [S0 + I0 + R0]
    
    
    for i in range(1, num_iters):
        ks, ls, ms = params(t0, Ss[-1], Is[-1], Rs[-1], i*h, f1, f2, f3)

        S_new = (nextS(Ss[-1], ks[0], ks[1], ks[2], ks[3]))
        I_new = (nextI(Is[-1], ls[0], ls[1], ls[2], ls[3]))
        R_new = (nextR(Rs[-1], ms[0], ms[1], ms[2], ms[3]))


        if S_new < 0 or I_new < 0 or R_new < 0:
            break
#         print(i, S_new, I_new, R_new, i*h)

        Ss.append(S_new)
        Is.append(I_new)
        Rs.append(R_new)
        Ns.append(S_new+I_new+R_new)
        ts.append(t0 + h*i)
        
    return Ss, Is, Rs, ts

# %%
beta = 1
gamma = 0.1
h = 0.0025
num_iters = 500
Ss, Is, Rs, ts = SIR_model(num_iters, beta, gamma, 1000, 1, 0, 0, h)

# %%
plt.figure(figsize = [6, 4])
plt.plot(ts, Ss, label = "S(t)")
plt.plot(ts, Is, label = "I(t)")
plt.plot(ts, Rs, label = "R(t)")

plt.grid()
plt.legend()
plt.xlabel("Time")
plt.ylabel("Size")
plt.title("SIR model")

plt.show()

# %%
## animation
fig, ax = plt.subplots(figsize=(6, 4), dpi=80)

def update(frame):
    ax.clear()
    
    ax.set_xlim([0, 4])
    ax.set_ylim([0, 1000])
    
    if frame < len(Ss):
        ax.plot(ts[:frame], Ss[:frame], label = "S(t)")
    else:
        ax.plot(ts, Ss, label = "S(t)")
        
    if frame < len(Is):
        ax.plot(ts[:frame], Is[:frame], label = "I(t)")
    else:
        ax.plot(ts, Is, label = "S(t)")
        
    if frame < len(Rs):
        ax.plot(ts[:frame], Rs[:frame], label = "R(t)")
    else:
        ax.plot(ts, Rs, label = "S(t)")
        
    ax.set_title('SIR epidemioloski model')
    ax.set_xlabel('Vreme')
    ax.set_ylabel('Populacija')
    ax.legend()
    ax.grid(True)

# %%
ani = animation.FuncAnimation(fig, update, frames=max(len(Ss), len(Is)) + 60, repeat=False, interval=h * 10)
ani.save('animation.gif', fps=30, writer='pillow')

# %%
#PHASE PLOTTING

# %%
import numpy as np

# %%
y1 = np.linspace(0, 1, 20)
y2 = np.linspace(0, 1, 20)
x, y = np.meshgrid(y1, y2)
u = np.zeros(len(x))
v = np.zeros(len(y))

for i in range(1, len(x)):
    Yprime = [ts[i], (Ss[i], Is[i])]
#     print(Yprime)
    u[i] = Yprime[0] 
    v[i] = Yprime[1][0]
# plt.quiver(x, y, u, v)
print(len(x), len(y), len(u), len(v))
plt.quiver(x, y, u, v)
# Out:
# 20
# 20 20 20 20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 16
#      14 # plt.quiver(x, y, u, v)
#      15 print(len(x), len(y), len(u), len(v))
# ---> 16 plt.quiver(x, y, u, v)
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2779, in quiver(data, *args, **kwargs)
#    2777 @_copy_docstring_and_deprecators(Axes.quiver)
#    2778 def quiver(*args, data=None, **kwargs):
# -> 2779     __ret = gca().quiver(
#    2780         *args, **({"data": data} if data is not None else {}),
#    2781         **kwargs)
#    2782     sci(__ret)
#    2783     return __ret
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:1437, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1434 @functools.wraps(func)
#    1435 def inner(ax, *args, data=None, **kwargs):
#    1436     if data is None:
# -> 1437         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439     bound = new_sig.bind(ax, *args, **kwargs)
#    1440     auto_label = (bound.arguments.get(label_namer)
#    1441                   or bound.kwargs.get(label_namer))
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:5109, in Axes.quiver(self, *args, **kwargs)
#    5107 # Make sure units are handled for x and y values
#    5108 args = self._quiver_units(args, kwargs)
# -> 5109 q = mquiver.Quiver(self, *args, **kwargs)
#    5110 self.add_collection(q, autolim=True)
#    5111 self._request_autoscale_view()
#
# File /usr/lib/python3/dist-packages/matplotlib/quiver.py:517, in Quiver.__init__(self, ax, scale, headwidth, headlength, headaxislength, minshaft, minlength, units, scale_units, angles, width, color, pivot, *args, **kwargs)
#     514 super().__init__([], offsets=self.XY, offset_transform=self.transform,
#     515                  closed=False, **kwargs)
#     516 self.polykw = kwargs
# --> 517 self.set_UVC(U, V, C)
#     518 self._dpi_at_last_init = None
#
# File /usr/lib/python3/dist-packages/matplotlib/quiver.py:567, in Quiver.set_UVC(self, U, V, C)
#     565 for name, var in zip(('U', 'V', 'C'), (U, V, C)):
#     566     if not (var is None or var.size == self.N or var.size == 1):
# --> 567         raise ValueError(f'Argument {name} has a size {var.size}'
#     568                          f' which does not match {self.N},'
#     569                          ' the number of arrow positions')
#     571 mask = ma.mask_or(U.mask, V.mask, copy=False, shrink=True)
#     572 if C is not None:
#
# ValueError: Argument U has a size 20 which does not match 400, the number of arrow positions

# %%
for i in range(shape1):
    for j in range(shape2):
        dxdtAtX = dynamicsStateSpace([[X0[i, j], X1[i, j]]],0)
        dX0[i, j] = dxdtAtX[0]
        dX1[i, j] = dxdtAtX[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[162], line 4
#       2 for j in range(shape2):
#       3     dxdtAtX = dynamicsStateSpace([[X0[i, j], X1[i, j]]],0)
# ----> 4     dX0[i, j] = dxdtAtX[0]
#       5     dX1[i, j] = dxdtAtX[1]
#
# ValueError: setting an array element with a sequence.

# %%
plt.figure(figsize=(5, 5))
# plot the phase portrait
plt.quiver(X0,X1,dX0,dX1,color='b')
# adjust the axis limits
plt.xlim(0,1)
plt.ylim(0,1)
# insert the title
plt.title('SIR Phase Portrait', fontsize=14)
# set the axis labels
plt.xlabel("S(t) Suspectible")
plt.ylabel("I(t) Infected")
# adjust the font size of x and y axes
plt.tick_params(axis='both', which='major', labelsize=14)
# insert legend
# plt.legend(fontsize=14)
# save figure
# plt.savefig('phasePortrait.png',dpi=600)
plt.show()
